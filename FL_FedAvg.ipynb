# %%
import tensorflow as tf
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
import os
import gc

# Enhanced Configuration
DATA_PATH = "C:/Users/musab/PycharmProjects/DataScienceGame/LOHITH_NEW/archive/Data"
CENTRAL_MODEL_PATH = "central_alzheimer_model(new).keras"
NUM_CLIENTS = 4
ROUNDS = 10  # Increased from 5 to 20
CLIENT_EPOCHS = 5  # Increased from 1 to 10
BATCH_SIZE = 32
TARGET_SIZE = (224, 224)
LEARNING_RATE = 0.0001
STEPS_PER_EPOCH = 50  # Reduced steps to accommodate more epochs

def create_client_datasets():
    """Create client datasets with enhanced augmentation"""
    clients = []
    for client_id in range(NUM_CLIENTS):
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True,
            vertical_flip=True,
            brightness_range=[0.8, 1.2],
            validation_split=0.2
        )
        
        train_gen = train_datagen.flow_from_directory(
            DATA_PATH,
            target_size=TARGET_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='binary',
            subset='training',
            shuffle=True,
            seed=42 + client_id
        )
        
        val_gen = train_datagen.flow_from_directory(
            DATA_PATH,
            target_size=TARGET_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='binary',
            subset='validation',
            shuffle=False,
            seed=42
        )
        
        print(f"\nClient {client_id} Data:")
        print(f"Training samples: {train_gen.samples}")
        print(f"Validation samples: {val_gen.samples}")
        print(f"Class distribution: {train_gen.class_indices}")
        
        clients.append({
            'train': train_gen,
            'val': val_gen,
            'train_steps': len(train_gen),
            'val_steps': len(val_gen)
        })
    return clients

def prepare_global_model():
    """Load and enhance existing central model"""
    global_model = load_model(CENTRAL_MODEL_PATH)
    
    # Architecture adaptation with enhanced layer
    if not any(isinstance(layer, GlobalAveragePooling2D) for layer in global_model.layers):
        print("Enhancing model architecture...")
        base_model = Model(inputs=global_model.inputs, 
                         outputs=global_model.layers[-2].output)
        x = GlobalAveragePooling2D()(base_model.output)
        x = Dense(128, activation='relu')(x)  # Added dense layer
        predictions = Dense(1, activation='sigmoid')(x)
        global_model = Model(inputs=base_model.input, outputs=predictions)
    
    global_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )
    return global_model

def federated_training():
    print("\n=== Enhanced Federated Learning ===")
    print(f"Running {ROUNDS} rounds with {CLIENT_EPOCHS} epochs per client")
    
    clients = create_client_datasets()
    global_model = prepare_global_model()
    
    # Enhanced tracking
    history = {
        'round': [],
        'val_accuracy': [],
        'val_auc': [],
        'client_losses': [[] for _ in range(NUM_CLIENTS)],
        'client_accuracies': [[] for _ in range(NUM_CLIENTS)]
    }
    
    # Baseline evaluation
    baseline_val = global_model.evaluate(clients[0]['val'], verbose=0)
    print(f"\nBaseline - Accuracy: {baseline_val[1]:.4f}, AUC: {baseline_val[2]:.4f}")
    
    for round in range(ROUNDS):
        print(f"\n=== Round {round+1}/{ROUNDS} ===")
        client_weights = []
        client_samples = []
        
        # Client training with progress bar
        for client_id in range(NUM_CLIENTS):
            print(f"\nClient {client_id} Training (Epochs: {CLIENT_EPOCHS})...")
            local_model = tf.keras.models.clone_model(global_model)
            local_model.set_weights(global_model.get_weights())
            local_model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                loss='binary_crossentropy',
                metrics=['accuracy']
            )
            
            history_local = local_model.fit(
                clients[client_id]['train'],
                steps_per_epoch=min(STEPS_PER_EPOCH, clients[client_id]['train_steps']),
                epochs=CLIENT_EPOCHS,
                verbose=1,
                validation_data=clients[client_id]['val'],
                validation_steps=min(20, clients[client_id]['val_steps'])
            )
            
            client_weights.append(local_model.get_weights())
            client_samples.append(clients[client_id]['train'].samples)
            history['client_losses'][client_id].append(history_local.history['loss'][-1])
            history['client_accuracies'][client_id].append(history_local.history['accuracy'][-1])
            
            del local_model
            gc.collect()
        
        # Enhanced weighted averaging
        avg_weights = [
            np.average(
                [weights[i] for weights in client_weights],
                axis=0,
                weights=client_samples
            )
            for i in range(len(client_weights[0]))
        ]
        global_model.set_weights(avg_weights)
        
        # Comprehensive evaluation
        val_results = global_model.evaluate(clients[0]['val'], verbose=0)
        history['round'].append(round)
        history['val_accuracy'].append(val_results[1])
        history['val_auc'].append(val_results[2])
        
        print(f"\nRound {round+1} Results:")
        print(f"Validation Accuracy: {val_results[1]:.4f}")
        print(f"Validation AUC: {val_results[2]:.4f}")
        
        # Periodic full evaluation
        if (round+1) % 5 == 0:  # Every 5 rounds
            val_gen = clients[0]['val']
            val_gen.reset()
            y_pred = (global_model.predict(val_gen, verbose=0) > 0.5).astype(int)
            print("\nDetailed Classification Report:")
            print(classification_report(val_gen.labels, y_pred, 
                                      target_names=val_gen.class_indices.keys()))
    
    # Save final model in modern format
    global_model.save('alzheimer_model_FedAvg_4Clients.keras')
    print("\nSaved enhanced model as 'alzheimer_model_FedAvg_4Clients.keras'")
    
    # Enhanced visualization
    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 3, 1)
    plt.plot(history['round'], history['val_accuracy'], 'b-o', label='Accuracy')
    plt.plot(history['round'], history['val_auc'], 'r-s', label='AUC')
    plt.title('Global Model Performance')
    plt.xlabel('Federation Round')
    plt.ylabel('Score')
    plt.legend()
    
    plt.subplot(1, 3, 2)
    for client_id in range(NUM_CLIENTS):
        plt.plot(history['round'], history['client_accuracies'][client_id], 
                label=f'Client {client_id}')
    plt.title('Client Training Accuracies')
    plt.xlabel('Federation Round')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 3, 3)
    for client_id in range(NUM_CLIENTS):
        plt.plot(history['round'], history['client_losses'][client_id],
                label=f'Client {client_id}')
    plt.title('Client Training Losses')
    plt.xlabel('Federation Round')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('enhanced_training_progress.png', dpi=300)
    plt.show()
    
    return global_model

if __name__ == "__main__":
    # Run enhanced federated training
    final_model = federated_training()
    
    # Final comprehensive evaluation
    print("\n=== Final Model Evaluation ===")
    print("Model ready for deployment with:")
    print(f"- {ROUNDS} federation rounds")
    print(f"- {CLIENT_EPOCHS} epochs per client")
    print(f"- {NUM_CLIENTS} participating clients")
# Out:
# === Enhanced Federated Learning ===
# Running 10 rounds with 5 epochs per client
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 0 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 1 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 2 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 3 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
#
# Baseline - Accuracy: 0.5419, AUC: 0.7418
#
# === Round 1/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.6576 - loss: 0.7093 - val_accuracy: 0.6562 - val_loss: 0.5910
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.7641 - loss: 0.4908 - val_accuracy: 0.6531 - val_loss: 0.6593
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.7718 - loss: 0.5149 - val_accuracy: 0.7547 - val_loss: 0.4998
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 344ms/step - accuracy: 0.8292 - loss: 0.4153 - val_accuracy: 0.6187 - val_loss: 0.6894
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.8047 - loss: 0.4297 - val_accuracy: 0.4109 - val_loss: 1.0807
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.7020 - loss: 0.6580 - val_accuracy: 0.6656 - val_loss: 0.5991
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 382ms/step - accuracy: 0.7874 - loss: 0.5157 - val_accuracy: 0.5578 - val_loss: 0.8127
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - accuracy: 0.8045 - loss: 0.4518 - val_accuracy: 0.7391 - val_loss: 0.5109
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.7769 - loss: 0.4993 - val_accuracy: 0.5656 - val_loss: 0.7487
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8047 - loss: 0.4591 - val_accuracy: 0.4406 - val_loss: 0.9821
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - accuracy: 0.7202 - loss: 0.6267 - val_accuracy: 0.7437 - val_loss: 0.4963
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 386ms/step - accuracy: 0.7639 - loss: 0.5050 - val_accuracy: 0.7078 - val_loss: 0.6054
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 374ms/step - accuracy: 0.7668 - loss: 0.5051 - val_accuracy: 0.6656 - val_loss: 0.6159
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 350ms/step - accuracy: 0.7883 - loss: 0.4724 - val_accuracy: 0.5453 - val_loss: 0.7583
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 305ms/step - accuracy: 0.7975 - loss: 0.4643 - val_accuracy: 0.4250 - val_loss: 1.0213
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - accuracy: 0.7109 - loss: 0.6429 - val_accuracy: 0.6672 - val_loss: 0.5921
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 382ms/step - accuracy: 0.7844 - loss: 0.5363 - val_accuracy: 0.6297 - val_loss: 0.6936
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.8132 - loss: 0.4583 - val_accuracy: 0.6922 - val_loss: 0.6053
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 348ms/step - accuracy: 0.7793 - loss: 0.5026 - val_accuracy: 0.5391 - val_loss: 0.8371
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8100 - loss: 0.4521 - val_accuracy: 0.4516 - val_loss: 0.9670
#
# Round 1 Results:
# Validation Accuracy: 0.6985
# Validation AUC: 0.7745
#
# === Round 2/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.8263 - loss: 0.4210 - val_accuracy: 0.7766 - val_loss: 0.4366
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 375ms/step - accuracy: 0.7886 - loss: 0.4936 - val_accuracy: 0.6578 - val_loss: 0.6334
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.8087 - loss: 0.4322 - val_accuracy: 0.7937 - val_loss: 0.4197
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8094 - loss: 0.4396 - val_accuracy: 0.5813 - val_loss: 0.7199
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8192 - loss: 0.4265 - val_accuracy: 0.4641 - val_loss: 0.9262
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - accuracy: 0.8032 - loss: 0.4492 - val_accuracy: 0.7234 - val_loss: 0.4822
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8055 - loss: 0.4249 - val_accuracy: 0.6609 - val_loss: 0.6066
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - accuracy: 0.7654 - loss: 0.5329 - val_accuracy: 0.6500 - val_loss: 0.6407
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - accuracy: 0.7852 - loss: 0.4585 - val_accuracy: 0.5328 - val_loss: 0.7614
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8129 - loss: 0.4363 - val_accuracy: 0.5109 - val_loss: 0.8482
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.7695 - loss: 0.4972 - val_accuracy: 0.6359 - val_loss: 0.6346
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.7933 - loss: 0.4457 - val_accuracy: 0.6516 - val_loss: 0.6116
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.7812 - loss: 0.4628 - val_accuracy: 0.8172 - val_loss: 0.4145
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8004 - loss: 0.4572 - val_accuracy: 0.5297 - val_loss: 0.8362
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.7690 - loss: 0.4696 - val_accuracy: 0.4437 - val_loss: 0.9242
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - accuracy: 0.7823 - loss: 0.4785 - val_accuracy: 0.7031 - val_loss: 0.5136
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.7832 - loss: 0.4839 - val_accuracy: 0.6328 - val_loss: 0.6504
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.7918 - loss: 0.4679 - val_accuracy: 0.6734 - val_loss: 0.5813
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8235 - loss: 0.4329 - val_accuracy: 0.5625 - val_loss: 0.7243
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 306ms/step - accuracy: 0.8185 - loss: 0.4454 - val_accuracy: 0.4516 - val_loss: 0.9267
#
# Round 2 Results:
# Validation Accuracy: 0.6974
# Validation AUC: 0.7905
#
# === Round 3/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.8099 - loss: 0.4366 - val_accuracy: 0.8062 - val_loss: 0.4410
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.7997 - loss: 0.4360 - val_accuracy: 0.7031 - val_loss: 0.5368
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.8281 - loss: 0.4134 - val_accuracy: 0.6797 - val_loss: 0.5672
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.8013 - loss: 0.4543 - val_accuracy: 0.6344 - val_loss: 0.6152
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.7984 - loss: 0.4362 - val_accuracy: 0.4922 - val_loss: 0.8368
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - accuracy: 0.7905 - loss: 0.4587 - val_accuracy: 0.7516 - val_loss: 0.4732
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8184 - loss: 0.4470 - val_accuracy: 0.6125 - val_loss: 0.6740
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 0.8057 - loss: 0.4636 - val_accuracy: 0.7094 - val_loss: 0.5468
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.8330 - loss: 0.4035 - val_accuracy: 0.5953 - val_loss: 0.6880
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.7969 - loss: 0.4282 - val_accuracy: 0.4172 - val_loss: 0.9402
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.8082 - loss: 0.4560 - val_accuracy: 0.7422 - val_loss: 0.4957
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8111 - loss: 0.4438 - val_accuracy: 0.5922 - val_loss: 0.7370
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.8119 - loss: 0.4372 - val_accuracy: 0.7828 - val_loss: 0.4504
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8458 - loss: 0.4177 - val_accuracy: 0.6000 - val_loss: 0.6948
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.7989 - loss: 0.4611 - val_accuracy: 0.5094 - val_loss: 0.8189
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - accuracy: 0.7978 - loss: 0.4668 - val_accuracy: 0.6906 - val_loss: 0.5517
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8063 - loss: 0.4269 - val_accuracy: 0.7391 - val_loss: 0.4956
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 364ms/step - accuracy: 0.8109 - loss: 0.4429 - val_accuracy: 0.7797 - val_loss: 0.4450
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 352ms/step - accuracy: 0.8089 - loss: 0.4520 - val_accuracy: 0.5297 - val_loss: 0.7592
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 306ms/step - accuracy: 0.8081 - loss: 0.4406 - val_accuracy: 0.5234 - val_loss: 0.8100
#
# Round 3 Results:
# Validation Accuracy: 0.7097
# Validation AUC: 0.7945
#
# === Round 4/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.7996 - loss: 0.4522 - val_accuracy: 0.8297 - val_loss: 0.3933
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.7999 - loss: 0.4585 - val_accuracy: 0.7094 - val_loss: 0.5251
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - accuracy: 0.8280 - loss: 0.4173 - val_accuracy: 0.7516 - val_loss: 0.5108
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.7990 - loss: 0.4615 - val_accuracy: 0.6141 - val_loss: 0.6459
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8035 - loss: 0.4528 - val_accuracy: 0.4563 - val_loss: 0.8991
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.8136 - loss: 0.4349 - val_accuracy: 0.7859 - val_loss: 0.4494
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8073 - loss: 0.4223 - val_accuracy: 0.6500 - val_loss: 0.6159
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.7904 - loss: 0.4907 - val_accuracy: 0.7437 - val_loss: 0.4962
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8288 - loss: 0.4202 - val_accuracy: 0.7000 - val_loss: 0.5398
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8461 - loss: 0.3937 - val_accuracy: 0.4703 - val_loss: 0.8524
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.7814 - loss: 0.4774 - val_accuracy: 0.8031 - val_loss: 0.4279
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 382ms/step - accuracy: 0.8144 - loss: 0.4171 - val_accuracy: 0.6687 - val_loss: 0.5892
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.8067 - loss: 0.4542 - val_accuracy: 0.7750 - val_loss: 0.4709
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 349ms/step - accuracy: 0.7810 - loss: 0.4680 - val_accuracy: 0.5922 - val_loss: 0.6833
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 306ms/step - accuracy: 0.8040 - loss: 0.4334 - val_accuracy: 0.5297 - val_loss: 0.7601
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - accuracy: 0.8200 - loss: 0.4326 - val_accuracy: 0.8297 - val_loss: 0.3824
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8047 - loss: 0.4433 - val_accuracy: 0.5984 - val_loss: 0.6775
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - accuracy: 0.8064 - loss: 0.4531 - val_accuracy: 0.7234 - val_loss: 0.5410
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8102 - loss: 0.4412 - val_accuracy: 0.6172 - val_loss: 0.6635
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8082 - loss: 0.4416 - val_accuracy: 0.5000 - val_loss: 0.7982
#
# Round 4 Results:
# Validation Accuracy: 0.7066
# Validation AUC: 0.8023
#
# === Round 5/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 0.8084 - loss: 0.4457 - val_accuracy: 0.7641 - val_loss: 0.4618
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.8112 - loss: 0.4289 - val_accuracy: 0.6062 - val_loss: 0.6607
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 364ms/step - accuracy: 0.8012 - loss: 0.4412 - val_accuracy: 0.7250 - val_loss: 0.5223
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.7909 - loss: 0.4440 - val_accuracy: 0.6641 - val_loss: 0.5914
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.8264 - loss: 0.4032 - val_accuracy: 0.4672 - val_loss: 0.8719
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.7984 - loss: 0.4414 - val_accuracy: 0.8203 - val_loss: 0.3965
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8016 - loss: 0.4505 - val_accuracy: 0.6953 - val_loss: 0.5365
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.8114 - loss: 0.4357 - val_accuracy: 0.7937 - val_loss: 0.4429
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8384 - loss: 0.4111 - val_accuracy: 0.7203 - val_loss: 0.5004
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8163 - loss: 0.4589 - val_accuracy: 0.5813 - val_loss: 0.7294
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.7946 - loss: 0.4520 - val_accuracy: 0.8094 - val_loss: 0.4066
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 382ms/step - accuracy: 0.8261 - loss: 0.4360 - val_accuracy: 0.6547 - val_loss: 0.5901
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.7975 - loss: 0.4682 - val_accuracy: 0.7344 - val_loss: 0.5102
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8450 - loss: 0.3906 - val_accuracy: 0.7625 - val_loss: 0.4585
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.8167 - loss: 0.4278 - val_accuracy: 0.4922 - val_loss: 0.8164
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - accuracy: 0.8143 - loss: 0.4524 - val_accuracy: 0.8203 - val_loss: 0.3881
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8229 - loss: 0.4457 - val_accuracy: 0.5813 - val_loss: 0.6783
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.8125 - loss: 0.4439 - val_accuracy: 0.6844 - val_loss: 0.5759
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8001 - loss: 0.4686 - val_accuracy: 0.6922 - val_loss: 0.5466
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8074 - loss: 0.4443 - val_accuracy: 0.5016 - val_loss: 0.7858
#
# Round 5 Results:
# Validation Accuracy: 0.7107
# Validation AUC: 0.8100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#     Demented       0.71      0.67      0.69      2745
# Non Demented       0.69      0.73      0.71      2745
#
#     accuracy                           0.70      5490
#    macro avg       0.70      0.70      0.70      5490
# weighted avg       0.70      0.70      0.70      5490
#
#
# === Round 6/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.7730 - loss: 0.4733 - val_accuracy: 0.8969 - val_loss: 0.3199
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.8118 - loss: 0.4435 - val_accuracy: 0.7531 - val_loss: 0.4694
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - accuracy: 0.8265 - loss: 0.4190 - val_accuracy: 0.7625 - val_loss: 0.4832
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 343ms/step - accuracy: 0.8248 - loss: 0.4085 - val_accuracy: 0.6734 - val_loss: 0.5956
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 300ms/step - accuracy: 0.8371 - loss: 0.3933 - val_accuracy: 0.4766 - val_loss: 0.8020
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - accuracy: 0.8243 - loss: 0.4043 - val_accuracy: 0.8281 - val_loss: 0.3938
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 375ms/step - accuracy: 0.8327 - loss: 0.3961 - val_accuracy: 0.7625 - val_loss: 0.4371
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.7919 - loss: 0.4554 - val_accuracy: 0.7219 - val_loss: 0.5302
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 343ms/step - accuracy: 0.8298 - loss: 0.4287 - val_accuracy: 0.6859 - val_loss: 0.5449
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.8257 - loss: 0.4394 - val_accuracy: 0.4547 - val_loss: 0.8587
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - accuracy: 0.8295 - loss: 0.4093 - val_accuracy: 0.8906 - val_loss: 0.3320
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 382ms/step - accuracy: 0.8212 - loss: 0.4259 - val_accuracy: 0.7234 - val_loss: 0.4997
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - accuracy: 0.8167 - loss: 0.4159 - val_accuracy: 0.7391 - val_loss: 0.5278
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.8138 - loss: 0.4249 - val_accuracy: 0.6562 - val_loss: 0.5913
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8335 - loss: 0.4063 - val_accuracy: 0.5016 - val_loss: 0.8229
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.8064 - loss: 0.4433 - val_accuracy: 0.7219 - val_loss: 0.5171
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 382ms/step - accuracy: 0.8104 - loss: 0.4511 - val_accuracy: 0.7063 - val_loss: 0.5203
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.7962 - loss: 0.4598 - val_accuracy: 0.7359 - val_loss: 0.5163
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8361 - loss: 0.4098 - val_accuracy: 0.7016 - val_loss: 0.5620
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8284 - loss: 0.4203 - val_accuracy: 0.4812 - val_loss: 0.7949
#
# Round 6 Results:
# Validation Accuracy: 0.7036
# Validation AUC: 0.8037
#
# === Round 7/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.8299 - loss: 0.4077 - val_accuracy: 0.7203 - val_loss: 0.5188
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.7904 - loss: 0.4573 - val_accuracy: 0.7031 - val_loss: 0.5525
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.8439 - loss: 0.3979 - val_accuracy: 0.7484 - val_loss: 0.5030
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 344ms/step - accuracy: 0.8205 - loss: 0.4344 - val_accuracy: 0.6484 - val_loss: 0.5858
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8118 - loss: 0.4360 - val_accuracy: 0.4344 - val_loss: 0.9105
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.8204 - loss: 0.4090 - val_accuracy: 0.8406 - val_loss: 0.3859
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 374ms/step - accuracy: 0.8437 - loss: 0.3943 - val_accuracy: 0.6469 - val_loss: 0.6226
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - accuracy: 0.8046 - loss: 0.4401 - val_accuracy: 0.7781 - val_loss: 0.4738
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.8115 - loss: 0.4392 - val_accuracy: 0.6313 - val_loss: 0.6453
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 300ms/step - accuracy: 0.8228 - loss: 0.4318 - val_accuracy: 0.4812 - val_loss: 0.8290
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.8114 - loss: 0.4334 - val_accuracy: 0.8922 - val_loss: 0.3314
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8185 - loss: 0.4306 - val_accuracy: 0.6438 - val_loss: 0.6263
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 0.8286 - loss: 0.4331 - val_accuracy: 0.7047 - val_loss: 0.5526
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 344ms/step - accuracy: 0.8336 - loss: 0.4026 - val_accuracy: 0.6703 - val_loss: 0.5805
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 300ms/step - accuracy: 0.8134 - loss: 0.4450 - val_accuracy: 0.4984 - val_loss: 0.8089
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - accuracy: 0.8071 - loss: 0.4223 - val_accuracy: 0.8156 - val_loss: 0.4146
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.8408 - loss: 0.4229 - val_accuracy: 0.6859 - val_loss: 0.5839
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - accuracy: 0.8225 - loss: 0.4342 - val_accuracy: 0.7125 - val_loss: 0.5460
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8185 - loss: 0.4168 - val_accuracy: 0.5078 - val_loss: 0.8024
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8185 - loss: 0.4171 - val_accuracy: 0.4750 - val_loss: 0.8699
#
# Round 7 Results:
# Validation Accuracy: 0.7228
# Validation AUC: 0.8097
#
# === Round 8/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - accuracy: 0.8092 - loss: 0.4222 - val_accuracy: 0.7266 - val_loss: 0.5129
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.8107 - loss: 0.4333 - val_accuracy: 0.6484 - val_loss: 0.6108
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 0.7898 - loss: 0.4437 - val_accuracy: 0.7641 - val_loss: 0.4851
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8116 - loss: 0.4291 - val_accuracy: 0.6938 - val_loss: 0.5536
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8343 - loss: 0.4420 - val_accuracy: 0.4703 - val_loss: 0.8299
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - accuracy: 0.8263 - loss: 0.4249 - val_accuracy: 0.8297 - val_loss: 0.4010
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8138 - loss: 0.4340 - val_accuracy: 0.7375 - val_loss: 0.4793
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.8363 - loss: 0.4050 - val_accuracy: 0.6750 - val_loss: 0.5876
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 344ms/step - accuracy: 0.8132 - loss: 0.4385 - val_accuracy: 0.6625 - val_loss: 0.5797
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8076 - loss: 0.4655 - val_accuracy: 0.4922 - val_loss: 0.7872
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - accuracy: 0.8087 - loss: 0.4525 - val_accuracy: 0.9141 - val_loss: 0.2993
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8193 - loss: 0.4244 - val_accuracy: 0.6328 - val_loss: 0.6127
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - accuracy: 0.8154 - loss: 0.4412 - val_accuracy: 0.7563 - val_loss: 0.4805
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.8092 - loss: 0.4627 - val_accuracy: 0.6875 - val_loss: 0.5696
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.8151 - loss: 0.4209 - val_accuracy: 0.4891 - val_loss: 0.7954
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - accuracy: 0.8268 - loss: 0.4177 - val_accuracy: 0.7516 - val_loss: 0.4955
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8317 - loss: 0.4100 - val_accuracy: 0.6922 - val_loss: 0.5321
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.8147 - loss: 0.4252 - val_accuracy: 0.7453 - val_loss: 0.4931
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 350ms/step - accuracy: 0.8186 - loss: 0.4219 - val_accuracy: 0.6906 - val_loss: 0.5557
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8283 - loss: 0.4340 - val_accuracy: 0.5375 - val_loss: 0.7557
#
# Round 8 Results:
# Validation Accuracy: 0.7095
# Validation AUC: 0.8047
#
# === Round 9/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.8429 - loss: 0.4077 - val_accuracy: 0.8016 - val_loss: 0.4020
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8199 - loss: 0.4226 - val_accuracy: 0.6609 - val_loss: 0.6025
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.8042 - loss: 0.4343 - val_accuracy: 0.8031 - val_loss: 0.4513
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8060 - loss: 0.4251 - val_accuracy: 0.7156 - val_loss: 0.5181
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8144 - loss: 0.4374 - val_accuracy: 0.5016 - val_loss: 0.7666
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - accuracy: 0.8141 - loss: 0.4361 - val_accuracy: 0.8344 - val_loss: 0.3847
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8297 - loss: 0.4177 - val_accuracy: 0.6672 - val_loss: 0.6132
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.8094 - loss: 0.4352 - val_accuracy: 0.7437 - val_loss: 0.5142
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8231 - loss: 0.4078 - val_accuracy: 0.6812 - val_loss: 0.5681
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.8349 - loss: 0.3961 - val_accuracy: 0.5234 - val_loss: 0.7575
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - accuracy: 0.8266 - loss: 0.3936 - val_accuracy: 0.8297 - val_loss: 0.3856
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.8097 - loss: 0.4328 - val_accuracy: 0.6672 - val_loss: 0.6113
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.8057 - loss: 0.4289 - val_accuracy: 0.7141 - val_loss: 0.5339
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.8183 - loss: 0.4246 - val_accuracy: 0.6562 - val_loss: 0.5940
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.8018 - loss: 0.4459 - val_accuracy: 0.4500 - val_loss: 0.8310
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.8136 - loss: 0.4434 - val_accuracy: 0.8687 - val_loss: 0.3529
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.8199 - loss: 0.4328 - val_accuracy: 0.7047 - val_loss: 0.5523
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - accuracy: 0.8196 - loss: 0.4218 - val_accuracy: 0.6906 - val_loss: 0.5706
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.8313 - loss: 0.4320 - val_accuracy: 0.7109 - val_loss: 0.5356
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8224 - loss: 0.4041 - val_accuracy: 0.4656 - val_loss: 0.8319
#
# Round 9 Results:
# Validation Accuracy: 0.7126
# Validation AUC: 0.8092
#
# === Round 10/10 ===
#
# Client 0 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.8014 - loss: 0.4592 - val_accuracy: 0.7922 - val_loss: 0.4312
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.7999 - loss: 0.4452 - val_accuracy: 0.7297 - val_loss: 0.5011
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - accuracy: 0.8398 - loss: 0.3939 - val_accuracy: 0.6906 - val_loss: 0.5634
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 348ms/step - accuracy: 0.8321 - loss: 0.4203 - val_accuracy: 0.6531 - val_loss: 0.6094
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.8163 - loss: 0.4268 - val_accuracy: 0.4828 - val_loss: 0.8306
#
# Client 1 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 0.8054 - loss: 0.4472 - val_accuracy: 0.8500 - val_loss: 0.3754
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.8004 - loss: 0.4478 - val_accuracy: 0.5875 - val_loss: 0.6893
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - accuracy: 0.8291 - loss: 0.4177 - val_accuracy: 0.7563 - val_loss: 0.5008
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.7961 - loss: 0.4503 - val_accuracy: 0.7453 - val_loss: 0.4896
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8165 - loss: 0.4176 - val_accuracy: 0.5141 - val_loss: 0.7641
#
# Client 2 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.8005 - loss: 0.4616 - val_accuracy: 0.8562 - val_loss: 0.3736
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 381ms/step - accuracy: 0.8056 - loss: 0.4345 - val_accuracy: 0.6984 - val_loss: 0.5600
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 0.8118 - loss: 0.4173 - val_accuracy: 0.8203 - val_loss: 0.4186
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.7954 - loss: 0.4536 - val_accuracy: 0.6656 - val_loss: 0.5869
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.8211 - loss: 0.4312 - val_accuracy: 0.4500 - val_loss: 0.8279
#
# Client 3 Training (Epochs: 5)...
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 400ms/step - accuracy: 0.8246 - loss: 0.4342 - val_accuracy: 0.7766 - val_loss: 0.4851
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 384ms/step - accuracy: 0.8216 - loss: 0.4306 - val_accuracy: 0.6625 - val_loss: 0.6000
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.7945 - loss: 0.4646 - val_accuracy: 0.7563 - val_loss: 0.5094
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.8273 - loss: 0.4055 - val_accuracy: 0.6250 - val_loss: 0.6149
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.8442 - loss: 0.3880 - val_accuracy: 0.5453 - val_loss: 0.7186
#
# Round 10 Results:
# Validation Accuracy: 0.6929
# Validation AUC: 0.8029
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#     Demented       0.72      0.65      0.68      2745
# Non Demented       0.68      0.74      0.71      2745
#
#     accuracy                           0.70      5490
#    macro avg       0.70      0.70      0.70      5490
# weighted avg       0.70      0.70      0.70      5490
#
#
# Saved enhanced model as 'alzheimer_model_FedAvg_4Clients.keras'
# === Final Model Evaluation ===
# Model ready for deployment with:
# - 10 federation rounds
# - 5 epochs per client
# - 4 participating clients

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# ===============================
# Configs
# ===============================
MODEL_PATH = "alzheimer_model_FedAvg_4Clients.keras"
DATA_PATH = "C:/Users/musab/PycharmProjects/DataScienceGame/LOHITH_NEW/archive/Data"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42  # For reproducibility

# ===============================
# 1. Load the model
# ===============================
print("📦 Loading model...")
model = load_model(MODEL_PATH)

# (Optional but recommended) Recompile to restore metrics if needed
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
print("✅ Model loaded!")

# ===============================
# 2. Prepare validation data
# ===============================
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

val_gen = datagen.flow_from_directory(
    DATA_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    shuffle=False,   # Important for correct prediction-label alignment
    seed=SEED
)

# ===============================
# 3. Make predictions
# ===============================
print("🔍 Predicting...")
pred_probs = model.predict(val_gen)
preds = (pred_probs > 0.5).astype(int).flatten()
y_true = val_gen.classes

# ===============================
# 4. Evaluation Metrics
# ===============================
print("\n📊 Classification Report:")
print(classification_report(y_true, preds, target_names=list(val_gen.class_indices.keys())))

print("\n📈 ROC AUC Score:", roc_auc_score(y_true, pred_probs))

# ===============================
# 5. Confusion Matrix
# ===============================
cm = confusion_matrix(y_true, preds)
labels = list(val_gen.class_indices.keys())

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title("🧠 Confusion Matrix - Alzheimer's Detection")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# 📦 Loading model...
# ✅ Model loaded!
# Found 5490 images belonging to 2 classes.
# 🔍 Predicting...
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 18 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#     Demented       0.74      0.93      0.83      2745
# Non Demented       0.91      0.68      0.78      2745
#
#     accuracy                           0.80      5490
#    macro avg       0.82      0.80      0.80      5490
# weighted avg       0.82      0.80      0.80      5490
#
#
# 📈 ROC AUC Score: 0.8679290380589314
# C:\Users\musab\AppData\Local\Temp\ipykernel_26936\945479058.py:73: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
