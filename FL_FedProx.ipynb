# %%
import tensorflow as tf
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import Progbar
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
import os
import gc

# Configuration
DATA_PATH = "C:/Users/musab/PycharmProjects/DataScienceGame/LOHITH_NEW/archive/Data"
CENTRAL_MODEL_PATH = "central_alzheimer_model(new).keras"
NUM_CLIENTS = 4
ROUNDS = 10
CLIENT_EPOCHS = 5
BATCH_SIZE = 32
TARGET_SIZE = (224, 224)
LEARNING_RATE = 0.0001
STEPS_PER_EPOCH = 50
FEDPROX_MU = 0.01  # Proximal term weight (μ)

def create_client_datasets():
    """Create client datasets with enhanced augmentation"""
    clients = []
    for client_id in range(NUM_CLIENTS):
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True,
            vertical_flip=True,
            brightness_range=[0.8, 1.2],
            validation_split=0.2
        )
        
        train_gen = train_datagen.flow_from_directory(
            DATA_PATH,
            target_size=TARGET_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='binary',
            subset='training',
            shuffle=True,
            seed=42 + client_id
        )
        
        val_gen = train_datagen.flow_from_directory(
            DATA_PATH,
            target_size=TARGET_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='binary',
            subset='validation',
            shuffle=False,
            seed=42
        )
        
        print(f"\nClient {client_id} Data:")
        print(f"Training samples: {train_gen.samples}")
        print(f"Validation samples: {val_gen.samples}")
        print(f"Class distribution: {train_gen.class_indices}")
        
        clients.append({
            'train': train_gen,
            'val': val_gen,
            'train_steps': len(train_gen),
            'val_steps': len(val_gen)
        })
    return clients

def prepare_global_model():
    """Load and enhance existing central model"""
    global_model = load_model(CENTRAL_MODEL_PATH)
    
    # Architecture adaptation with enhanced layer
    if not any(isinstance(layer, GlobalAveragePooling2D) for layer in global_model.layers):
        print("Enhancing model architecture...")
        base_model = Model(inputs=global_model.inputs, 
                         outputs=global_model.layers[-2].output)
        x = GlobalAveragePooling2D()(base_model.output)
        x = Dense(128, activation='relu')(x)  # Added dense layer
        predictions = Dense(1, activation='sigmoid')(x)
        global_model = Model(inputs=base_model.input, outputs=predictions)
    
    global_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )
    return global_model

def fedprox_loss(y_true, y_pred, model_weights, global_weights, mu=FEDPROX_MU):
    """Calculate FedProx loss with proximal term"""
    # Standard binary crossentropy
    base_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred))
    
    # Proximal term (L2 difference between local and global weights)
    proximal_term = 0.0
    for w, gw in zip(model_weights, global_weights):
        proximal_term += tf.reduce_sum(tf.square(w - gw))
    
    return base_loss + (mu / 2) * proximal_term

def train_client_with_fedprox(client_data, global_model, client_id, epochs=CLIENT_EPOCHS):
    """Train a client model with FedProx optimization"""
    # Clone the global model
    local_model = tf.keras.models.clone_model(global_model)
    local_model.set_weights(global_model.get_weights())
    
    # Get global weights for proximal term
    global_weights = global_model.get_weights()
    
    # Create optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    
    # Metrics tracking
    train_loss = []
    train_accuracy = []
    
    print(f"\nClient {client_id} Training with FedProx (μ={FEDPROX_MU})")
    
    # Calculate total steps
    total_steps = min(STEPS_PER_EPOCH, client_data['train_steps'])
    
    for epoch in range(epochs):
        print(f"\nEpoch {epoch+1}/{epochs}")
        
        # Initialize metrics
        epoch_loss = []
        epoch_accuracy = []
        
        # Create progress bar
        progress_bar = Progbar(total_steps, stateful_metrics=['loss', 'accuracy'])
        
        for step, (images, labels) in enumerate(client_data['train']):
            if step >= total_steps:
                break
                
            # Ensure proper shapes
            labels = tf.reshape(labels, (-1, 1))
            
            with tf.GradientTape() as tape:
                predictions = local_model(images, training=True)
                loss = fedprox_loss(
                    labels,
                    predictions, 
                    local_model.trainable_weights,
                    global_weights
                )
                # Calculate accuracy
                acc = tf.reduce_mean(tf.keras.metrics.binary_accuracy(labels, predictions))
            
            gradients = tape.gradient(loss, local_model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, local_model.trainable_variables))
            
            # Store metrics
            epoch_loss.append(loss.numpy().item())  # Convert to Python scalar
            epoch_accuracy.append(acc.numpy().item())  # Convert to Python scalar
            
            # Update progress bar
            progress_bar.update(
                step + 1,
                values=[
                    ('loss', np.mean(epoch_loss)),
                    ('accuracy', np.mean(epoch_accuracy))
                ]
            )
        
        # Store epoch metrics
        train_loss.append(np.mean(epoch_loss))
        train_accuracy.append(np.mean(epoch_accuracy))
    
    return local_model.get_weights(), client_data['train'].samples, train_loss, train_accuracy

def federated_training_with_fedprox():
    print("\n=== Federated Learning with FedProx ===")
    print(f"Running {ROUNDS} rounds with {CLIENT_EPOCHS} epochs per client")
    print(f"Proximal term μ: {FEDPROX_MU}")
    
    clients = create_client_datasets()
    global_model = prepare_global_model()
    
    # Enhanced tracking
    history = {
        'round': [],
        'val_accuracy': [],
        'val_auc': [],
        'client_losses': [[] for _ in range(NUM_CLIENTS)],
        'client_accuracies': [[] for _ in range(NUM_CLIENTS)]
    }
    
    # Baseline evaluation
    baseline_val = global_model.evaluate(clients[0]['val'], verbose=0)
    print(f"\nBaseline - Accuracy: {baseline_val[1]:.4f}, AUC: {baseline_val[2]:.4f}")
    
    for round_num in range(ROUNDS):
        print(f"\n=== Round {round_num+1}/{ROUNDS} ===")
        client_weights = []
        client_samples = []
        
        # Client training with FedProx
        for client_id in range(NUM_CLIENTS):
            weights, samples, losses, accuracies = train_client_with_fedprox(
                clients[client_id], 
                global_model,
                client_id
            )
            client_weights.append(weights)
            client_samples.append(samples)
            
            # Store client metrics
            history['client_losses'][client_id].extend(losses)
            history['client_accuracies'][client_id].extend(accuracies)
        
        # Weighted averaging (FedAvg)
        avg_weights = []
        for i in range(len(client_weights[0])):
            layer_weights = np.array([weights[i] for weights in client_weights])
            avg_weights.append(np.average(
                layer_weights,
                axis=0,
                weights=client_samples
            ))
        
        global_model.set_weights(avg_weights)
        
        # Comprehensive evaluation
        val_results = global_model.evaluate(clients[0]['val'], verbose=0)
        history['round'].append(round_num)
        history['val_accuracy'].append(val_results[1])
        history['val_auc'].append(val_results[2])
        
        print(f"\nRound {round_num+1} Results:")
        print(f"Validation Accuracy: {val_results[1]:.4f}")
        print(f"Validation AUC: {val_results[2]:.4f}")
        
        # Periodic full evaluation
        if (round_num+1) % 5 == 0:  # Every 5 rounds
            val_gen = clients[0]['val']
            val_gen.reset()
            y_pred = (global_model.predict(val_gen, verbose=0) > 0.5).astype(int)
            print("\nDetailed Classification Report:")
            print(classification_report(val_gen.labels, y_pred, 
                                      target_names=val_gen.class_indices.keys()))
    
    # Save final model
    global_model.save('alzheimer_model_fedprox_4Clients.keras')
    print("\nSaved FedProx model as 'alzheimer_model_fedprox_4Clients.keras'")
    
    # Visualization
    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 3, 1)
    plt.plot(history['round'], history['val_accuracy'], 'b-o', label='Accuracy')
    plt.plot(history['round'], history['val_auc'], 'r-s', label='AUC')
    plt.title('Global Model Performance (FedProx)')
    plt.xlabel('Federation Round')
    plt.ylabel('Score')
    plt.legend()
    
    plt.subplot(1, 3, 2)
    for client_id in range(NUM_CLIENTS):
        plt.plot(range(len(history['client_accuracies'][client_id])), 
                history['client_accuracies'][client_id], 
                label=f'Client {client_id}')
    plt.title('Client Training Accuracies')
    plt.xlabel('Training Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.subplot(1, 3, 3)
    for client_id in range(NUM_CLIENTS):
        plt.plot(range(len(history['client_losses'][client_id])), 
                history['client_losses'][client_id],
                label=f'Client {client_id}')
    plt.title('Client Training Losses')
    plt.xlabel('Training Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('fedprox_training_progress.png', dpi=300)
    plt.show()
    
    return global_model

if __name__ == "__main__":
    # Run federated training with FedProx
    final_model = federated_training_with_fedprox()
    
    # Final evaluation
    print("\n=== Final FedProx Model Evaluation ===")
    print("Model ready for deployment with:")
    print(f"- {ROUNDS} federation rounds")
    print(f"- {CLIENT_EPOCHS} epochs per client")
    print(f"- {NUM_CLIENTS} participating clients")
    print(f"- FedProx μ parameter: {FEDPROX_MU}")
# Out:
# === Federated Learning with FedProx ===
# Running 10 rounds with 5 epochs per client
# Proximal term μ: 0.01
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 0 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 1 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 2 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# Found 21960 images belonging to 2 classes.
# Found 5490 images belonging to 2 classes.
#
# Client 3 Data:
# Training samples: 21960
# Validation samples: 5490
# Class distribution: {'Demented': 0, 'Non Demented': 1}
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Baseline - Accuracy: 0.5419, AUC: 0.7418
#
# === Round 1/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.5772 - accuracy: 0.7506
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.5032 - accuracy: 0.7869
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 466ms/step - loss: 0.4652 - accuracy: 0.8044
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 468ms/step - loss: 0.4620 - accuracy: 0.7906
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 469ms/step - loss: 0.4532 - accuracy: 0.7937
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 467ms/step - loss: 0.5667 - accuracy: 0.7512
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 466ms/step - loss: 0.4744 - accuracy: 0.8000
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4912 - accuracy: 0.7869
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 466ms/step - loss: 0.4905 - accuracy: 0.7906
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 468ms/step - loss: 0.4687 - accuracy: 0.7975
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.5416 - accuracy: 0.7456
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4925 - accuracy: 0.7812
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4946 - accuracy: 0.7725
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4639 - accuracy: 0.7913
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4775 - accuracy: 0.7806
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.5906 - accuracy: 0.7356
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.5031 - accuracy: 0.7750
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4778 - accuracy: 0.7925
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.5096 - accuracy: 0.7750
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4923 - accuracy: 0.7819
#
# Round 1 Results:
# Validation Accuracy: 0.6807
# Validation AUC: 0.7697
#
# === Round 2/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4635 - accuracy: 0.7913
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4631 - accuracy: 0.8050
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4601 - accuracy: 0.7969
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4420 - accuracy: 0.8075
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4627 - accuracy: 0.7969
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 466ms/step - loss: 0.4367 - accuracy: 0.8144
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4593 - accuracy: 0.7956
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4346 - accuracy: 0.8131
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4602 - accuracy: 0.8006
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4258 - accuracy: 0.8169
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4990 - accuracy: 0.7794
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4553 - accuracy: 0.8006
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4509 - accuracy: 0.7950
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4567 - accuracy: 0.8025
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4565 - accuracy: 0.8100
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4579 - accuracy: 0.7969
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4446 - accuracy: 0.8119
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4338 - accuracy: 0.8063
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4460 - accuracy: 0.8131
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4658 - accuracy: 0.7856
#
# Round 2 Results:
# Validation Accuracy: 0.7046
# Validation AUC: 0.7889
#
# === Round 3/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4477 - accuracy: 0.8194
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 460ms/step - loss: 0.4496 - accuracy: 0.8037
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4190 - accuracy: 0.8094
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 456ms/step - loss: 0.4457 - accuracy: 0.8069
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4139 - accuracy: 0.8219
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4432 - accuracy: 0.8013
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4799 - accuracy: 0.7819
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4560 - accuracy: 0.8037
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 454ms/step - loss: 0.4419 - accuracy: 0.8094
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4463 - accuracy: 0.8056
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4490 - accuracy: 0.7981
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4465 - accuracy: 0.8106
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4509 - accuracy: 0.7937
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 457ms/step - loss: 0.4549 - accuracy: 0.8056
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4259 - accuracy: 0.8181
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4482 - accuracy: 0.8050
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4338 - accuracy: 0.8169
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4443 - accuracy: 0.8056
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 456ms/step - loss: 0.4474 - accuracy: 0.8081
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4405 - accuracy: 0.8106
#
# Round 3 Results:
# Validation Accuracy: 0.7022
# Validation AUC: 0.7939
#
# === Round 4/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4468 - accuracy: 0.7981
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4501 - accuracy: 0.8044
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4470 - accuracy: 0.8144
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4270 - accuracy: 0.8206
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4412 - accuracy: 0.7994
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4192 - accuracy: 0.8313
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4513 - accuracy: 0.7969
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4623 - accuracy: 0.7887
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4650 - accuracy: 0.7969
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4362 - accuracy: 0.8281
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4450 - accuracy: 0.8050
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4611 - accuracy: 0.8187
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4365 - accuracy: 0.8006
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4512 - accuracy: 0.8137
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4406 - accuracy: 0.8113
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 24s 479ms/step - loss: 0.4347 - accuracy: 0.8131
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 24s 470ms/step - loss: 0.4481 - accuracy: 0.8087
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4387 - accuracy: 0.8144
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4375 - accuracy: 0.8125
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4558 - accuracy: 0.8019
#
# Round 4 Results:
# Validation Accuracy: 0.7098
# Validation AUC: 0.7989
#
# === Round 5/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4501 - accuracy: 0.8081
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 460ms/step - loss: 0.4131 - accuracy: 0.8237
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4280 - accuracy: 0.8287
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4270 - accuracy: 0.8150
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4423 - accuracy: 0.8169
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4408 - accuracy: 0.8150
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4196 - accuracy: 0.8200
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4241 - accuracy: 0.8163
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4181 - accuracy: 0.8263
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4378 - accuracy: 0.8219
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4365 - accuracy: 0.8100
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4417 - accuracy: 0.7975
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4414 - accuracy: 0.8069
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4146 - accuracy: 0.8263
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4275 - accuracy: 0.8175
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4542 - accuracy: 0.8019
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4180 - accuracy: 0.8306
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4194 - accuracy: 0.8125
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4488 - accuracy: 0.8144
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 24s 474ms/step - loss: 0.4436 - accuracy: 0.8050
#
# Round 5 Results:
# Validation Accuracy: 0.7064
# Validation AUC: 0.8002
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#     Demented       0.71      0.69      0.70      2745
# Non Demented       0.70      0.72      0.71      2745
#
#     accuracy                           0.70      5490
#    macro avg       0.70      0.70      0.70      5490
# weighted avg       0.70      0.70      0.70      5490
#
#
# === Round 6/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 455ms/step - loss: 0.4290 - accuracy: 0.8119
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 453ms/step - loss: 0.4810 - accuracy: 0.7925
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4332 - accuracy: 0.8075
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4352 - accuracy: 0.8181
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4133 - accuracy: 0.8325
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4518 - accuracy: 0.7956
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 456ms/step - loss: 0.4394 - accuracy: 0.8156
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4255 - accuracy: 0.8137
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4279 - accuracy: 0.8156
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4655 - accuracy: 0.8000
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4059 - accuracy: 0.8187
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 456ms/step - loss: 0.4380 - accuracy: 0.8169
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4347 - accuracy: 0.8100
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4274 - accuracy: 0.8119
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4390 - accuracy: 0.8069
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4233 - accuracy: 0.8206
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 455ms/step - loss: 0.4503 - accuracy: 0.8056
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4495 - accuracy: 0.8169
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4163 - accuracy: 0.8131
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4184 - accuracy: 0.8337
#
# Round 6 Results:
# Validation Accuracy: 0.7353
# Validation AUC: 0.8074
#
# === Round 7/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 457ms/step - loss: 0.4495 - accuracy: 0.8119
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4327 - accuracy: 0.8169
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.3981 - accuracy: 0.8375
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4375 - accuracy: 0.8106
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4272 - accuracy: 0.8125
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4351 - accuracy: 0.8181
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4369 - accuracy: 0.8131
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4381 - accuracy: 0.8213
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4406 - accuracy: 0.8131
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4342 - accuracy: 0.8100
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4093 - accuracy: 0.8306
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4373 - accuracy: 0.8187
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4126 - accuracy: 0.8206
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4449 - accuracy: 0.7987
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4365 - accuracy: 0.8150
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 470ms/step - loss: 0.4356 - accuracy: 0.8175
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 470ms/step - loss: 0.4398 - accuracy: 0.8144
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 24s 477ms/step - loss: 0.4102 - accuracy: 0.8319
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 35s 711ms/step - loss: 0.4348 - accuracy: 0.8194
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 759ms/step - loss: 0.4404 - accuracy: 0.8125
#
# Round 7 Results:
# Validation Accuracy: 0.7142
# Validation AUC: 0.8057
#
# === Round 8/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 760ms/step - loss: 0.4346 - accuracy: 0.8181
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 761ms/step - loss: 0.4503 - accuracy: 0.7937
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 756ms/step - loss: 0.4196 - accuracy: 0.8219
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 33s 654ms/step - loss: 0.4264 - accuracy: 0.8275
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4242 - accuracy: 0.8244
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4475 - accuracy: 0.8206
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.3756 - accuracy: 0.8488
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4090 - accuracy: 0.8450
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4436 - accuracy: 0.7981
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4194 - accuracy: 0.8213
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4265 - accuracy: 0.8194
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4650 - accuracy: 0.8025
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4332 - accuracy: 0.8131
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4107 - accuracy: 0.8194
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4311 - accuracy: 0.8175
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 24s 472ms/step - loss: 0.4324 - accuracy: 0.8200
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4448 - accuracy: 0.8144
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.3992 - accuracy: 0.8306
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4210 - accuracy: 0.8225
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 460ms/step - loss: 0.4344 - accuracy: 0.8094
#
# Round 8 Results:
# Validation Accuracy: 0.7046
# Validation AUC: 0.8075
#
# === Round 9/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 448ms/step - loss: 0.4196 - accuracy: 0.8200
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4353 - accuracy: 0.8137
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4371 - accuracy: 0.8225
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4450 - accuracy: 0.8163
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4412 - accuracy: 0.8150
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 454ms/step - loss: 0.4159 - accuracy: 0.8263
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4229 - accuracy: 0.8250
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4335 - accuracy: 0.8144
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4190 - accuracy: 0.8306
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4272 - accuracy: 0.8206
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 454ms/step - loss: 0.4052 - accuracy: 0.8219
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4097 - accuracy: 0.8250
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4359 - accuracy: 0.8081
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4117 - accuracy: 0.8387
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4235 - accuracy: 0.8231
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 452ms/step - loss: 0.4228 - accuracy: 0.8219
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.4392 - accuracy: 0.8106
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4313 - accuracy: 0.8200
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 24s 471ms/step - loss: 0.4280 - accuracy: 0.8237
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 466ms/step - loss: 0.4344 - accuracy: 0.8144
#
# Round 9 Results:
# Validation Accuracy: 0.7082
# Validation AUC: 0.8060
#
# === Round 10/10 ===
#
# Client 0 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 0.4121 - accuracy: 0.8194
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4149 - accuracy: 0.8175
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 461ms/step - loss: 0.4151 - accuracy: 0.8213
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4460 - accuracy: 0.8119
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4257 - accuracy: 0.8187
#
# Client 1 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4397 - accuracy: 0.8019
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4293 - accuracy: 0.8237
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4234 - accuracy: 0.8275
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4428 - accuracy: 0.8050
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4291 - accuracy: 0.8125
#
# Client 2 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - loss: 0.4355 - accuracy: 0.8181
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4243 - accuracy: 0.8256
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4330 - accuracy: 0.8200
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4140 - accuracy: 0.8294
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4242 - accuracy: 0.8150
#
# Client 3 Training with FedProx (μ=0.01)
#
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4214 - accuracy: 0.8181
#
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 462ms/step - loss: 0.4073 - accuracy: 0.8306
#
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4124 - accuracy: 0.8319
#
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 463ms/step - loss: 0.4482 - accuracy: 0.8031
#
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - loss: 0.4249 - accuracy: 0.8181
#
# Round 10 Results:
# Validation Accuracy: 0.7131
# Validation AUC: 0.8088
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#     Demented       0.71      0.70      0.71      2745
# Non Demented       0.70      0.72      0.71      2745
#
#     accuracy                           0.71      5490
#    macro avg       0.71      0.71      0.71      5490
# weighted avg       0.71      0.71      0.71      5490
#
#
# Saved FedProx model as 'alzheimer_model_fedprox_4Clients.keras'
# === Final FedProx Model Evaluation ===
# Model ready for deployment with:
# - 10 federation rounds
# - 5 epochs per client
# - 4 participating clients
# - FedProx μ parameter: 0.01

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# ===============================
# Configs
# ===============================
MODEL_PATH = "alzheimer_model_fedprox_4Clients.keras"
DATA_PATH = "C:/Users/musab/PycharmProjects/DataScienceGame/LOHITH_NEW/archive/Data"
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42  # For reproducibility

# ===============================
# 1. Load the model
# ===============================
print("📦 Loading model...")
model = load_model(MODEL_PATH)

# (Optional but recommended) Recompile to restore metrics if needed
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
print("✅ Model loaded!")

# ===============================
# 2. Prepare validation data
# ===============================
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

val_gen = datagen.flow_from_directory(
    DATA_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    shuffle=False,   # Important for correct prediction-label alignment
    seed=SEED
)

# ===============================
# 3. Make predictions
# ===============================
print("🔍 Predicting...")
pred_probs = model.predict(val_gen)
preds = (pred_probs > 0.5).astype(int).flatten()
y_true = val_gen.classes

# ===============================
# 4. Evaluation Metrics
# ===============================
print("\n📊 Classification Report:")
print(classification_report(y_true, preds, target_names=list(val_gen.class_indices.keys())))

print("\n📈 ROC AUC Score:", roc_auc_score(y_true, pred_probs))

# ===============================
# 5. Confusion Matrix
# ===============================
cm = confusion_matrix(y_true, preds)
labels = list(val_gen.class_indices.keys())

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title("🧠 Confusion Matrix - Alzheimer's Detection")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# 📦 Loading model...
# ✅ Model loaded!
# Found 5490 images belonging to 2 classes.
# 🔍 Predicting...
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 18 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#     Demented       0.76      0.90      0.82      2745
# Non Demented       0.88      0.71      0.78      2745
#
#     accuracy                           0.81      5490
#    macro avg       0.82      0.81      0.80      5490
# weighted avg       0.82      0.81      0.80      5490
#
#
# 📈 ROC AUC Score: 0.869255642814722
# C:\Users\musab\AppData\Local\Temp\ipykernel_36524\2541555759.py:73: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\musab\PycharmProjects\DataScienceGame\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
